# %%
import matplotlib.pyplot as pl
import numpy
from sklearn.model_selection import learning_curve, validation_curve
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit, train_test_split

# %%
train_mean = numpy.array([1.0105e-13,-1.4970e-11,-1.8456e-09,-3.7070e-08,3.3429e-08,-1.5088e-08,4.2720e-07,7.4135e-07,2.049e-08,-5.2155e-08])
train_std = numpy.array([6.9415e-13,8.818e-11,3.7359e-09,6.0646e-08,4.3383e-08,4.3363e-08,0.0003888,0.000740639,0.00077444,0.00109454429431176])
valid_mean = numpy.array([22.5110,1355.02188,-11537.3799,-106758.8046,-104247.664,-61231.9037,-1637.35616,0.0001231,0.000133,8.3399e-05])
valid_std = numpy.array([561.5823,2692.6794,38727.979,464777.4747,453578.105,266415.4670,5651.9264,0.0014,0.0014,0.0013856])
sizes = numpy.array([38,76,114,152,190,228,266,304,342,380])
shadow = valid_mean + valid_std
print(train_mean)
# Out:
# [  1.01050000e-13  -1.49700000e-11  -1.84560000e-09  -3.70700000e-08
#    3.34290000e-08  -1.50880000e-08   4.27200000e-07   7.41350000e-07
#    2.04900000e-08  -5.21550000e-08]

# %%
len(sizes)
# Out:
# 10

# %%
 # Create the figure window
fig = pl.figure(figsize=(20,20))

# Create three different models based on max_depth
#for k, depth in enumerate([1,3,6,10]):
        
    # Subplot the learning curve 
ax = fig.add_subplot(2, 1, 1)
ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Mean Error')
ax.plot(sizes, valid_mean, 'o-', color = 'g', label = 'Testing Mean Error')
ax.fill_between(sizes, train_mean - train_std, \
    train_mean + train_std, alpha = 0.15, color = 'r')
ax.fill_between(sizes, valid_mean - valid_std, \
    valid_mean + valid_std, alpha = 0.15, color = 'g')
        
    # Labels
ax.set_title('max_depth = ')
ax.set_xlabel('Number of Training Points')
ax.set_ylabel('r2_score')
ax.set_xlim([0, 400])
ax.set_ylim([-2e+5, 2e+3])
    
    # Visual aesthetics
ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
fig.tight_layout()

fig



ax = fig.add_subplot(2, 1, 2)
ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Mean Error')
ax.plot(sizes, valid_mean, 'o-', color = 'g', label = 'Testing Mean Error')
ax.fill_between(sizes, train_mean - train_std, \
    train_mean + train_std, alpha = 0.15, color = 'r')
ax.fill_between(sizes, valid_mean - valid_std, \
    valid_mean + valid_std, alpha = 0.15, color = 'g')
        
    # Labels
ax.set_title('max_depth = ')
ax.set_xlabel('Number of Training Points')
ax.set_ylabel('r2_score')
ax.set_xlim([0, 400])
ax.set_ylim([-5.9e+5, 4e+5])
    
    # Visual aesthetics
#ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
fig.tight_layout()

fig
