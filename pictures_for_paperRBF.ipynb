# %%
import matplotlib.pyplot as pl
import numpy as np
from sklearn.model_selection import learning_curve, validation_curve

# %%
sizes = numpy.array([40,80,120,160,200,240,280,320,360,400])
#sizes = numpy.array([120,160,200,240,280,320,360,400])

test_diffmean1 = np.array([396.83,638.48,1407.56,652.90,825.08,139.79,\
                           635.42,9.00,28.51,37.76])
test_diffmean2 = np.array([396.83,562.17,1074.29,129.39,308.76,224.91,\
                           151.21,67.76 ,23.87,68.55])
#test_diffmean3 = np.array([699.26,273.31,238.35,177.78,184.40,66.51,67.41,18.30])
test_diffmean3 = np.array([406.06,468.69,699.26,273.31,238.35,177.78,184.40,66.51,67.41,18.30])


test_std3 = np.array([1012.86,828.12,610.42,439.56,276.13,108.12,92.09,25.76 ])

# %%
 # Create the figure window
fig = pl.figure(figsize=(10,10))

# Create three different models based on max_depth
#for k, depth in enumerate([1,3,6,10]):
        
    # Subplot the learning curve 

ax = fig.add_subplot(2, 1, 1)
ax.plot(sizes, test_diffmean1, 'o-', color = 'r', label = 'test_diffmean1')
ax.plot(sizes, test_diffmean2, 'o-', color = 'g', label = 'test_diffmean2')
ax.plot(sizes, test_diffmean3, 'o-', color = 'b', label = 'test_diffmean3')
#ax.fill_between(sizes, train_mean - train_std, \
    #train_mean + train_std, alpha = 0.15, color = 'r')
#ax.fill_between(sizes, valid_mean - valid_std, \
    #valid_mean + valid_std, alpha = 0.15, color = 'g')
        
    # Labels
#ax.set_title('max_depth = ')
ax.set_xlabel('Sample Number of Training Data Set')
ax.set_ylabel('Mean Error')
ax.set_xlim([0, 400])
ax.set_ylim([-10, 1700])
    
    # Visual aesthetics
#ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
fig.suptitle('Learning Curve of Model 1', fontsize = 16, y = 1.03)
fig.tight_layout()

fig


ax = fig.add_subplot(2, 1, 2)
#ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Mean Error')
ax.plot(sizes, valid_mean, 'o-', color = 'g', label = 'Testing Mean Error')
#ax.fill_between(sizes, train_mean - train_std, \
    #train_mean + train_std, alpha = 0.15, color = 'r')
ax.fill_between(sizes, valid_mean - valid_std, \
    valid_mean + valid_std, alpha = 0.15, color = 'g')
        
    # Labels
ax.set_title('max_depth = ')
ax.set_xlabel('Number of Training Points')
ax.set_ylabel('r2_score')
ax.set_xlim([0, 400])
ax.set_ylim([-5.9e+5, 4e+5])
    
    # Visual aesthetics
#ax.legend(bbox_to_anchor=(1.05, 2.05), loc='lower left', borderaxespad = 0.)
fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
fig.tight_layout()

fig

# %%
#----------------------------根据学习曲线确定模型1-----------------------------
fig = pl.figure(figsize=(6,4), dpi = 100)
ax = fig.add_subplot(1, 1, 1)
ax.plot(sizes, test_diffmean3, 'o-', color = 'g', label = 'test_diffmean3')
ax.fill_between(sizes, test_diffmean3 - test_std3/10, \
    test_diffmean3 + test_std3/10, alpha = 0.15, color = 'g')

#ax.set_title('max_depth = ')
ax.set_xlabel('Sample Number of Training Data Set')
ax.set_ylabel('Mean Error')
ax.set_xlim([100, 420])
ax.set_ylim([0, 850])

fig.suptitle('Learning Curve of Model 1', fontsize = 16, y = 1.03)
fig.tight_layout()

fig

# 以分辨率 72 来保存图片
# savefig("exercice_2.png",dpi=72)

# %%
#------------------------Model1在三个测试集上的预测结果------------------------
sizes = np.linspace(1, 20, 20,endpoint=True)

test_orig1 = np.array([1784.70,2902.97,3040.85,1512.64,3833.00,1494.33,3655.12,1510.32,\
                       3590.90,3021.73,1954.90,1952.57,2837.06,3631.80,2292.22,1490.15,\
                       2693.98,3309.52,3420.23,2680.69])
test_pred_orig1 = np.array([1780.80,2874.73,3030.70,1515.45,3833.39,1489.78,3652.27,\
                            1498.86,3593.02,3025.62,1926.14,1948.00,2842.40,3667.27,\
                            2293.19,1489.02,2692.04,3317.94,3402.89,2686.41])

test_orig2 = np.array([2711.10,1581.48,2482.22,2476.68,2073.77,2734.19,2777.65,2034.44,\
                       2772.98,2454.79,1785.98,3591.61,2366.14,1608.44,1564.37,1716.49,\
                       2755.37,1856.33,1768.99,1632.81 ])
test_pred_orig2 = np.array([2675.14,1561.28,2437.83,2440.05,2070.72,2772.85,2777.85,\
                            2025.15,2743.95,2473.34,1796.02,3571.57,2367.67,1560.53,\
                            1606.73,1723.97,2758.11,1819.86,1803.35,1671.40 ])

test_orig3 = np.array([2303.06,2996.28,3220.46,1744.46,2007.22,3397.60,2374.54,\
                       2911.04,2341.84,2751.21,1532.00,2485.38,2293.59,2026.29,\
                       3108.67,3207.91,3371.97,2197.45,2241.51,1605.44 ])
test_pred_orig3 = np.array([2286.51,3045.91,3269.12,1740.23,2002.69,3400.72,2400.04,\
                            2921.32,2345.23,2757.54,1533.03,2487.68,2281.95,2074.12,\
                            3127.39,3206.66,3366.48,2142.52,2201.45,1594.97 ])

test_std3 = np.array([1012.86,828.12,610.42,439.56,276.13,108.12,92.09,25.76 ])

valid_mean = np.array([22.5110,1355.02188,-11537.3799,-106758.8046,-104247.664,-61231.9037,-1637.35616,0.0001231,0.000133,8.3399e-05])
valid_std = np.array([561.5823,2692.6794,38727.979,464777.4747,453578.105,266415.4670,5651.9264,0.0014,0.0014,0.0013856])

# %%
test_diff1 = test_pred_orig1 - test_orig1
test_diff2 = test_pred_orig2 - test_orig2
test_diff3 = test_pred_orig3 - test_orig3

mean1= np.mean(abs(test_diff1))
mean2= np.mean(abs(test_diff2))
mean3= np.mean(abs(test_diff3))


print(mean1,mean2,mean3)
# Out:
# (9.000999999999987, 23.874000000000024, 18.296999999999947)

# %%
fig = pl.figure(figsize=(6,8), dpi = 100)
ax = fig.add_subplot(3, 1, 1)
ax.plot(sizes, test_orig1, 'o-', color = 'b', label = 'test_orig1')
ax.plot(sizes, test_pred_orig1, 'o-', color = 'g', label = 'test_pred_orig1')
ax.plot(sizes, test_diff1, 'o-', color = 'r', label = 'test_orig1')


#ax.set_title('max_depth = ')
ax.set_xlabel('Testing Data Set 1')
ax.set_ylabel('Initial Velosity')
ax.set_xlim([0, 23])
ax.set_ylim([-30, 3850])

fig.suptitle('Prediction of Model 1 on Testing Data Set 1', fontsize = 16, y = 1.03)
fig.tight_layout()

# 以分辨率 72 来保存图片
# savefig("exercice_2.png",dpi=72)

# %%
fig = pl.figure(figsize=(6,8), dpi = 100)

#---------------------------测试集1上的误差图---------------------------
ax = fig.add_subplot(3, 1, 1)

ax.plot(sizes, test_diff1, 'o-', color = 'g', label = 'error')

# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean1 = np.zeros(300)+mean1
ax.plot(X,test_diffmean1,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error = %s'%mean1, xy=(-0.4, mean1),\
            xycoords='data',xytext=(0, 23), textcoords='offset points')

#ax.set_title('Prediction of Model 1 on Testing Data Set 1 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 1')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1, 22])
ax.set_ylim([-38, 50])




ax.legend( loc='upper left', borderaxespad = 0.6)
fig.tight_layout()

fig

#---------------------------测试集2上的误差图---------------------------
ax = fig.add_subplot(3, 1, 2)

ax.plot(sizes, test_diff2, 'o-', color = 'g', label = 'error')
# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean2 = np.zeros(300)+mean2
ax.plot(X,test_diffmean2,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error =%s'%mean2, xy=(-1, mean2),\
            xycoords='data',xytext=(0, 23), textcoords='offset points')


#ax.set_title('Prediction of Model 1 on Testing Data Set 2 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 2')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1.5, 22])
ax.set_ylim([-55, 50])

ax.legend( loc='upper left', borderaxespad = 0.6)
fig.tight_layout()

fig

#---------------------------测试集3上的误差图---------------------------
ax = fig.add_subplot(3, 1, 3)

ax.plot(sizes, test_diff3, 'o-', color = 'g', label = 'error')
# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean3 = np.zeros(300)+mean3
ax.plot(X,test_diffmean3,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error %s'%mean3, xy=(20, mean3),\
            xycoords='data',xytext=(-66, 16), textcoords='offset points')

#ax.set_title('Prediction of Model 1 on Testing Data Set 3 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 3')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1, 22])
ax.set_ylim([-64, 65])

ax.legend( loc='upper right', borderaxespad = 0.6)
fig.suptitle('Prediction of Model 1 on 3 Testing Data Sets', fontsize = 12, y = 1.02)
fig.tight_layout()

fig

# %%
# ---------------------------电流数据----------------------------

#sizes = numpy.array([40,80,120,160,200,240,280,320,360,400])
sizes = numpy.array([120,160,200,240,280,320,360,400])

test_diffmean4 = np.array([15.29,4.37,2.76,2.84,1.33,3.36,1.27,1.51,0.99,1.15])
#test_diffmean5 = np.array([15.388,6.752,2.163,1.856,1.518,1.669,1.727,1.296,1.753,1.302])
test_diffmean5 = np.array([2.163,1.856,1.518,1.669,1.727,1.296,1.753,1.302])


test_std5 = np.array([4.85,5.73,1.65,6.59,1.84,2.14,1.39,1.55])
#test_std5 = np.array([19.32,6.43,4.85,5.73,1.65,6.59,1.84,2.14,1.39,1.55])

# %%
#----------------------------根据学习曲线确定模型2-----------------------------
fig = pl.figure(figsize=(6,4), dpi = 100)
ax = fig.add_subplot(1, 1, 1)
ax.plot(sizes, test_diffmean5, 'o-', color = 'g', label = 'test_diffmean5')
ax.fill_between(sizes, test_diffmean5 - test_std5, \
    test_diffmean5 + test_std5, alpha = 0.15, color = 'g')

#ax.set_title('max_depth = ')
ax.set_xlabel('Sample Number of Training Data Set')
ax.set_ylabel('Mean Error')
ax.set_xlim([0, 420])
ax.set_ylim([-7, 37])

fig.suptitle('Learning Curve of Model 2', fontsize = 16, y = 1.03)
fig.tight_layout()

fig

# 以分辨率 72 来保存图片
# savefig("exercice_2.png",dpi=72)

# %%
#------------------------Model1在三个测试集上的预测结果------------------------
sizes = np.linspace(1, 20, 20,endpoint=True)

test_diff4 = np.array([0.04,0.72,1.22,-0.48,2.40,-2.19,-0.04,2.26,-0.68,-1.21,0.14,\
                       -0.16,-0.19,1.09,-0.59,-3.40,0.63,0.21,1.70,-0.45 ])
test_diff5 = np.array([-0.69,2.35,-1.03,1.07,5.70,1.96,-0.09,0.65,0.34,-0.13,0.18,0.93,\
                       0.37,0.92,-3.41,-0.99,-0.48,-0.06,-3.85,0.74 ])
test_diff6 = np.array([0.57,0.92,-2.16,2.15,-1.00,0.52,3.48,-0.10,0.19,0.60,-0.66,\
                       0.29,0.03,0.57,-1.27,-1.71,-1.01,2.03,-0.25,-0.45 ])

mean4= np.mean(abs(test_diff4))
mean5= np.mean(abs(test_diff5))
mean6= np.mean(abs(test_diff6))

print(mean4, mean5, mean6)
# Out:
# (0.98999999999999999, 1.2969999999999999, 0.998)

# %%
fig = pl.figure(figsize=(6,8), dpi = 100)

#---------------------------测试集1上的误差图---------------------------
ax = fig.add_subplot(3, 1, 1)

ax.plot(sizes, test_diff4, 'o-', color = 'g', label = 'error')

# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean4 = np.zeros(300)+mean4
ax.plot(X,test_diffmean4,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error = %s'%mean4 , xy=(22, mean4),\
            xycoords='data',xytext=(-100, 17), textcoords='offset points')

#ax.set_title('Prediction of Model 1 on Testing Data Set 1 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 1')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1, 22])
ax.set_ylim([-4, 5.5])            #-2.1~2.4




ax.legend( loc='upper right', borderaxespad = 0.6)
fig.tight_layout()

fig

#---------------------------测试集2上的误差图---------------------------
ax = fig.add_subplot(3, 1, 2)

ax.plot(sizes, test_diff5, 'o-', color = 'g', label = 'error')
# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean5 = np.zeros(300)+mean5
ax.plot(X,test_diffmean5,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error = 1.30', xy=(22, mean5),\
            xycoords='data',xytext=(-100, 17), textcoords='offset points')


#ax.set_title('Prediction of Model 1 on Testing Data Set 2 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 2')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1, 22])
ax.set_ylim([-5, 7])         #-3.8~5.7
ax.legend( loc='upper right', borderaxespad = 0.6)
fig.tight_layout()

fig

#---------------------------测试集3上的误差图---------------------------
ax = fig.add_subplot(3, 1, 3)

ax.plot(sizes, test_diff6, 'o-', color = 'g', label = 'error')
# 插入均值线
X = np.linspace(0, 20, 300,endpoint=True)
test_diffmean6 = np.zeros(300)+mean6
ax.plot(X,test_diffmean6,color = 'C1', label = 'mean error')
#插入均值注释
ax.annotate('mean error = %s'%mean6, xy=(-0.4, mean6),\
            xycoords='data',xytext=(0, 22), textcoords='offset points')

#ax.set_title('Prediction of Model 1 on Testing Data Set 3 ', fontsize = 8)
ax.set_xlabel('Testing Data Set 3')
ax.set_ylabel('Prediction Error (m/s)')
ax.set_xlim([-1, 22])
ax.set_ylim([-4, 6.5])         #-2.16~3.48

ax.legend( loc='upper left', borderaxespad = 0.6)
fig.suptitle('Prediction of Model 1 on 3 Testing Data Sets', fontsize = 12, y = 1.02)
fig.tight_layout()

fig
